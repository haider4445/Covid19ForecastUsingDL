# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline

import plotly.offline as py
from plotly import tools
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px

pd.options.mode.chained_assignment = None
from Utils import count_parameters, cumulative_to_daily, daily_to_cumulative
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# import chart_studio
# chart_studio.tools.set_credentials_file(username='yelnady', api_key='YuOqqt1pIR5ps02vxLfY')
# chart_studio.tools.set_config_file(world_readable=False,
#                              sharing='public')

# %%
fips_codes = pd.read_csv('fips-codes.csv')[[' st',' stusps']].to_dict('split')['data']
fips_codes=dict(fips_codes)

def fips_to_code(x):
    return fips_codes[x].strip()
    
canadian_fips = [72, 78, 66, 69]

# %%
import chart_studio.plotly as py

cumulative_df = pd.read_csv('us-states.csv')

cumulative_df = cumulative_df[~cumulative_df['fips'].isin(canadian_fips)]

cumulative_df["StateCode"] = cumulative_df["fips"].apply(lambda x: get_state_codes(x))

cumulative_df["date"] = pd.to_datetime(cumulative_df["date"] , format="%Y-%m-%d").dt.date
cumulative_df["date"] = cumulative_df["date"].astype(str)

# cumulative_df = cumulative_df.groupby(["fips"])

fig = px.choropleth(cumulative_df,
                    locations=cumulative_df["StateCode"],
                    color=cumulative_df['cases'], 
                    locationmode="USA-states",
                    scope="usa",
                    animation_frame=cumulative_df['date'],
#                     hover_data = [cumulative_df['deaths'],cumulative_df['cases']],
                    color_continuous_scale='Reds',
                    range_color=[0,1000000]
                   )

layout = go.Layout(
    title=go.layout.Title(
        text="Cumulative count of COVID-19 cases in US states",
    ),
    font=dict(size=14),
)

fig.update_layout(layout)
# fig.show()
py.iplot(fig, filename = 'us-cases', auto_open=True)
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~yelnady/1.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
fig = px.choropleth(cumulative_df,
                    locations=cumulative_df["StateCode"],
                    color=cumulative_df['deaths'], 
                    locationmode="USA-states",
                    scope="usa",
                    animation_frame=cumulative_df['date'],
#                     hover_data = [cumulative_df['deaths'],cumulative_df['cases']],
                    color_continuous_scale='Reds',
                   )

layout = go.Layout(
    title=go.layout.Title(
        text="Cumulative count of COVID-19 cases in US states",
    ),
    font=dict(size=14),
)

fig.update_layout(layout)
# fig.show()
py.iplot(fig, filename = 'us-deaths', auto_open=True)
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~yelnady/49.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
state = 'VA'
vaccines_daily = pd.read_csv('us-vaccines.csv')
# vaccines_cumulative = daily_to_cumulative(vaccines_daily).reshape(-1,1)

# %%
vaccines_daily
# Out:
#        Entity Code         Day  daily_vaccinations
# 0     Alabama  NaN  2021-01-13                5906
# 1     Alabama  NaN  2021-01-14                7083
# 2     Alabama  NaN  2021-01-15                7478
# 3     Alabama  NaN  2021-01-16                7498
# 4     Alabama  NaN  2021-01-17                7509
# ...       ...  ...         ...                 ...
# 6778  Wyoming  NaN  2021-04-22                2905
# 6779  Wyoming  NaN  2021-04-23                2483
# 6780  Wyoming  NaN  2021-04-24                2471
# 6781  Wyoming  NaN  2021-04-25                2490
# 6782  Wyoming  NaN  2021-04-26                3532
#
# [6783 rows x 4 columns]

# %%
state_names_codes = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}
def state_to_code(x):
    return state_names_codes[x]=



cumulative_df = pd.read_csv('us-vaccines.csv')

cumulative_df = cumulative_df[~cumulative_df['fips'].isin(canadian_fips)]

cumulative_df["StateCode"] = cumulative_df["fips"].apply(lambda x: get_state_codes(x))
vaccines_cumulative = daily_to_cumulative(vaccines_daily).reshape(-1,1)
